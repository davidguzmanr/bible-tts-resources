# %% [markdown]
# ## Audios and timing files

# %%
from utils import download_audios

# %%
# 1) Parse HTML -> dict(name -> URL)
html_path = "html_files/audios/Apali.html"
links = download_audios.extract_artifact_links(html_path)

links
# Out:
# {'Matthew': {'url': 'https://openbible-api-1.biblica.com/artifactContent/62e2eabb5dafb527681c6e6d',
#   'section': 'New Testament - mp3'},
#  'Mark': {'url': 'https://openbible-api-1.biblica.com/artifactContent/62e2eabb5dafb527681c6e6f',
#   'section': 'New Testament - mp3'},
#  'Luke': {'url': 'https://openbible-api-1.biblica.com/artifactContent/62e2eabb5dafb527681c6e77',
#   'section': 'New Testament - mp3'},
#  'John': {'url': 'https://openbible-api-1.biblica.com/artifactContent/62e2eabb5dafb527681c6e70',
#   'section': 'New Testament - mp3'},
#  'Acts': {'url': 'https://openbible-api-1.biblica.com/artifactContent/62e2eabb5dafb527681c6e81',
#   'section': 'New Testament - mp3'},
#  'Romans': {'url': 'https://openbible-api-1.biblica.com/artifactContent/62e2eabb5dafb527681c6e7f',
#   'section': 'New Testament - mp3'},
#  '1 Corinthians': {'url': 'https://openbible-api-1.biblica.com/artifactContent/62e2eabb5dafb527681c6e74',
#   'section': 'New Testament - mp3'},
#  '2 Corinthians': {'url': 'https://openbible-api-1.biblica.com/artifactContent/62e2eabb5dafb527681c6e75',
#   'section': 'New Testament - mp3'},
#  'Galatians': {'url': 'https://openbible-api-1.biblica.com/artifactContent/62e2eabb5dafb527681c6e82',
#   'section': 'New Testament - mp3'},
#  'Ephesians': {'url': 'https://openbible-api-1.biblica.com/artifactContent/62e2eabb5dafb527681c6e86',
#   'section': 'New Testament - mp3'},
#  'Philippians': {'url': 'https://openbible-api-1.biblica.com/artifactContent/62e2eabb5dafb527681c6e73',
#   'section': 'New Testament - mp3'},
#  'Colossians': {'url': 'https://openbible-api-1.biblica.com/artifactContent/62e2eabb5dafb527681c6e76',
#   'section': 'New Testament - mp3'},
#  '1 Thessalonians': {'url': 'https://openbible-api-1.biblica.com/artifactContent/62e2eabb5dafb527681c6e79',
#   'section': 'New Testament - mp3'},
#  '2 Thessalonians': {'url': 'https://openbible-api-1.biblica.com/artifactContent/62e2eabb5dafb527681c6e7a',
#   'section': 'New Testament - mp3'},
#  '1 Timothy': {'url': 'https://openbible-api-1.biblica.com/artifactContent/62e2eabb5dafb527681c6e7b',
#   'section': 'New Testament - mp3'},
#  '2 Timothy': {'url': 'https://openbible-api-1.biblica.com/artifactContent/62e2eabb5dafb527681c6e7d',
#   'section': 'New Testament - mp3'},
#  'Titus': {'url': 'https://openbible-api-1.biblica.com/artifactContent/62e2eabb5dafb527681c6e89',
#   'section': 'New Testament - mp3'},
#  'Philemon': {'url': 'https://openbible-api-1.biblica.com/artifactContent/62e2eabb5dafb527681c6e71',
#   'section': 'New Testament - mp3'},
#  'Hebrews': {'url': 'https://openbible-api-1.biblica.com/artifactContent/62e2eabb5dafb527681c6e78',
#   'section': 'New Testament - mp3'},
#  'James': {'url': 'https://openbible-api-1.biblica.com/artifactContent/62e2eabb5dafb527681c6e87',
#   'section': 'New Testament - mp3'},
#  '1 Peter': {'url': 'https://openbible-api-1.biblica.com/artifactContent/62e2eabb5dafb527681c6e7c',
#   'section': 'New Testament - mp3'},
#  '2 Peter': {'url': 'https://openbible-api-1.biblica.com/artifactContent/62e2eabb5dafb527681c6e7e',
#   'section': 'New Testament - mp3'},
#  '1 John': {'url': 'https://openbible-api-1.biblica.com/artifactContent/62e2eabb5dafb527681c6e83',
#   'section': 'New Testament - mp3'},
#  '2 John': {'url': 'https://openbible-api-1.biblica.com/artifactContent/62e2eabb5dafb527681c6e84',
#   'section': 'New Testament - mp3'},
#  '3 John': {'url': 'https://openbible-api-1.biblica.com/artifactContent/62e2eabb5dafb527681c6e85',
#   'section': 'New Testament - mp3'},
#  'Jude': {'url': 'https://openbible-api-1.biblica.com/artifactContent/62e2eabb5dafb527681c6e72',
#   'section': 'New Testament - mp3'},
#  'Revelation': {'url': 'https://openbible-api-1.biblica.com/artifactContent/62e2eabb5dafb527681c6e6e',
#   'section': 'New Testament - mp3'},
#  'Genesis': {'url': 'https://openbible-api-1.biblica.com/artifactContent/62e2eabb5dafb527681c6e80',
#   'section': 'Old Testament - mp3'},
#  'Exodus': {'url': 'https://openbible-api-1.biblica.com/artifactContent/62e2eabb5dafb527681c6e88',
#   'section': 'Old Testament - mp3'}}

# %% [markdown]
# # Texts

# %%
from utils import downloads_texts

# %%
# 1) Parse HTML -> dict(name -> URL)
html_path = "html_files/texts/Toma.html"
links = downloads_texts.extract_artifact_links(html_path)

links
# Out:
# {}
